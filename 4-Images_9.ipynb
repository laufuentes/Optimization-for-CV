# %% [markdown]
# ### 0- Library importation

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 

from src.utils import *
from src.fcts import *
from src.dataframes import *

# %% [markdown]
# ### 1- Paths definition

# %%
paths = get_all_paths('Dataset_BUSI_with_GT/')
wav ='db1'
dfpath = "images/"+wav+"/dataframe_"+wav+".csv"

methods_thr = [Soft_thresholding, Hard_thresholding, XT]
thr = [VisuShrink, BayesShrink, thresholding_fct]

#Dataframe initialization  
#pd.DataFrame(columns=columns, index = None).to_csv(dfpath)

# %% [markdown]
# ### 2- Computation

# %%
for img_path in paths:
    all_train(img_path,dfpath, wav, methods_thr, thr)
# Out:
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
# ...

# %% [markdown]
# ### 3- Figure creation

# %%
df = pd.read_csv(dfpath)[pd.Index([c for c in pd.read_csv(dfpath).columns if c.split(':')[0]!='Unnamed'])]
df
# Out:
#          img_name    Threshold_type Threshold_function       EKI      SSIM  \
# 0   malignant(58)        VisuShrink  Soft_thresholding  0.999780  0.989994
# 1   malignant(58)       BayesShrink  Soft_thresholding  0.999730  0.961671
# 2   malignant(58)  thresholding_fct  Soft_thresholding  0.999730  0.961671
# 3   malignant(58)        VisuShrink  Hard_thresholding  0.999780  0.989994
# 4   malignant(58)       BayesShrink  Hard_thresholding  0.999731  0.961676
# 5   malignant(58)  thresholding_fct  Hard_thresholding  0.999780  0.989994
# 6   malignant(58)        VisuShrink                 XT  0.999780  0.989994
# 7   malignant(58)       BayesShrink                 XT  0.999798  0.989819
# 8   malignant(58)  thresholding_fct                 XT  0.999780  0.989994
# 9     benign(421)        VisuShrink  Soft_thresholding  0.998025  0.990606
# 10    benign(421)       BayesShrink  Soft_thresholding  0.997575  0.935708
# ...

# %%
df_9(df, wav).plt_Threshold_comparison_several()

# %%
df_9(df, wav).plt_Threshold_comparison()

# %%
df_9(df, wav).new
# Out:
#       VisuShrink_Soft_thresholding  VisuShrink_Hard_thresholding  \
# EKI                       0.997800                      0.997800
# SSIM                      0.989994                      0.989994
# MSE                       0.000089                      0.000089
# PSNR                     31.720682                     31.720682
#
#       VisuShrink_XT  BayesShrink_Soft_thresholding  \
# EKI        0.997800                       0.997499
# SSIM       0.989994                       0.935708
# MSE        0.000089                       0.000213
# PSNR      31.720682                      30.033087
#
#       BayesShrink_Hard_thresholding  BayesShrink_XT  \
# EKI                        0.997309        0.997885
# SSIM                       0.899234        0.974034
# MSE                        0.000213        0.000093
# PSNR                      21.418399       29.190400
#
#       thresholding_fct_Soft_thresholding  thresholding_fct_Hard_thresholding  \
# ...
