# %% [markdown]
# ### 0- Library importation

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

from src.utils import *
from src.fcts import *
from src.dataframes import *

# %% [markdown]
# ### 1- Paths definition

# %%
paths = get_all_paths('/Users/laurafuentesvicente/M2 Maths&IA/Optimization for CV/Dataset_BUSI_with_GT/')
dfpath = "/Users/laurafuentesvicente/M2 Maths&IA/Optimization for CV/Project/images/wavelets/dataframe_wavelets.csv"
columns = ['img_name', 'wavelet','EKI','SSIM', 'MSE', 'PSNR']

#Dataframe initialization
pd.DataFrame(columns=columns, index = None).to_csv(dfpath)

# %% [markdown]
# ### 2- Computation

# %%
for img_path in paths: 
    train_wavelet(img_path, dfpath)
# Out:
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laurafuentesvicente/opt/anaconda3/envs/torch_dev/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 for img_path in paths:
# ----> 2     train_wavelet(img_path, dfpath)
#
# File ~/M2 Maths&IA/Optimization for CV/Project/src/fcts.py:117, in train_wavelet(path_img, path_df)
#     114 level1 = [A1, H1, D1, V1]
#     115 level2 = [A2, H2, D2, V2]
# --> 117 final_img = train_one([level1,level2], img, thresholding_fct, XT, wav)
#     118 df.append({'img_name':path_img.split('/')[-1].split('.')[0], 'wavelet':wav, 'EKI':edge_keeping_index(img, final_img), 'SSIM': structural_similarity(color.rgb2gray(img), color.rgb2gray(final_img), win_size=7,data_range=img.max()), 'MSE':mean_squared_error(img, final_img), 'PSNR':peak_signal_noise_ratio(img, final_img)})
#     119 # Ajouter un titre pour chaque colonne
#
# File ~/M2 Maths&IA/Optimization for CV/Project/src/fcts.py:150, in train_one(tot, img, thr_type, thr_fct, wav)
#     148         D = l[3]
#     149         H = c
# --> 150         leveln.append(thr_fct(thr_type()))
#     151     new.append(leveln)
#     153 leveln1 = new[0]
#
# File ~/M2 Maths&IA/Optimization for CV/Project/src/fcts.py:38, in XT(tau)
#      36     return res_wav
#      37 inf_tau = np.where(np.abs(H) < tau)
# ---> 38 for i in inf_tau: res_wav[i] = H[i]*np.exp(nl * (np.abs(H[i]) - tau))
#      39 return res_wav
#
# KeyboardInterrupt:

# %% [markdown]
# ### 3- Figure creation

# %%
df = pd.read_csv(dfpath)[pd.Index([c for c in pd.read_csv(dfpath).columns if c.split(':')[0]!='Unnamed'])]
df_wavs = df_wavelets(df)

# %%
df_wavs.plt_wavelets_performance()

# %%
df_wavs.plt_Metric_wavelet_performance()
